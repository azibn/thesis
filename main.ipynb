# %% [markdown]
# # MSc Project Notebook

# %% [markdown]
# Steps of obtaining raw spectra and converting into radial velocities:
# - CCD cameras record the spectral data as flux (magnitude) and wavelength
#
#
# - We simulate a binary model accoridng to the [SB9 Catalogue](https://heasarc.gsfc.nasa.gov/W3Browse/all/sborbitcat.html) to fit it with the spectral data - this simulates the binary star.
# - Gaia observes a source on average 40 times, so a randomly generated array of 40 values (to replicate the 40 unique observations) is applied to the binary model.
# - Gaussian filter applied, and resample the spectra to 0.025nm from 0.001nm (RVS spectra resolution is 0.025nm and we want to replicate this).
# - Normalise the spectra. This is now our template spectra.
# - Doppler shift each of the now normalised spectra by each of the values of the 40 observations. We now get 40 different spectra.
# - Cross correlate these new spectra with the template spectra and therefore obtain 40 cross correlation functions.
#
# - We want to then shift the new CCF's to rest. Since we know the rest template, there is a shortcut but this idea would need to be developed for the real data cases (I think).

# %% [markdown]
# ### Importing packages:

# %%
from __future__ import print_function, division
from PyAstronomy import pyasl
import numpy as np
import statistics
import matplotlib.pylab as plt
import pandas as pd
from astropy.convolution import convolve
import scipy
import math
import spectres
np.warnings.filterwarnings('ignore') 
# %run -i 'Cross Correlation Function.py'
# %matplotlib inline
SEED = 42

# %% [markdown]
# Reading in the data:

# %%
data = pd.read_csv("xx03",delim_whitespace=True).rename(columns= {"sourceId": "wavelength", "57500450000": "flux"})
data.head()
# Out:
#    wavelength     flux
# 0     840.000  47622.0
# 1     840.001  47622.0
# 2     840.002  47622.0
# 3     840.003  47622.0
# 4     840.004  47622.0

# %% [markdown]
# Resolution of dataset is 0.001nm. In comparison, RVS resolution is 0.025nm. Sanity check of data:

# %%
data.plot(style='.',x='wavelength',y='flux',ms=0.8, figsize=(10,5))
_ = plt.show()

# %% [markdown]
# Single Star (can only see brighter star) - shifting wrt RV implies secondary (implied SB1 as we don't see both spectral data clearly, unlike SB2)
#
# In principle can apply this with SB2 but becomes more complicated as two templates will be moving as opposed to one, therefore simultaneous methods

# %% [markdown]
# Defining parameters:

# %%
sig_rvs = (860.5/11500.)/2.35482

# %% [markdown]
# ---

# %% [markdown]
# ### IDL to Python conversion (file: normspec.pro)

# %%
def norm_flux_array(data=data):
    flux_size = data.flux.size
    x1 = 25
    x2 = flux_size-1-25
    y1 = np.median(data.flux[0:51]) # first 50 data points
    y2 = np.median(data.flux[-51:-1]) # last 50 data points
    gradient = (y2-y1)/(x2-x1)
    first_flux_point = data.flux[0]

    linear_flux = np.zeros((flux_size),float)
    for i in range(0,flux_size-1):
        linear_flux[i] = first_flux_point + (gradient*i)
    norm_flux_array = data.flux/linear_flux  
    plt.figure(figsize=(10,5))
    plt.scatter(data.wavelength, norm_flux_array, s=1)
    plt.show()
    
norm_flux_array()

# %% [markdown]
# Normalising dataset:

# %% [markdown]
# Continuum normalisation. Approximating to original data.
# - Trying to compare absorption lines relative to template.
# - If continuum is more sloped in parts than other, parts not always treated equally.

# %% [markdown]
# ## Radial Velocity equation for Gaia's nominal mission duration:

# %%
def binary_model(gamma,K,P,tau):
    RV = []
    for t in np.arange(0,1825):
        v = (2*math.pi)*(t-tau)/P
        RV.append(gamma + K*np.cos(v))
    plt.figure(figsize=(20,2))
    plt.plot(RV)
    plt.xlabel('Period in Days', fontsize=14)
    plt.ylabel('Radial Velocity in km/s', fontsize=14)
    return RV
    #plt.show()
binary = binary_model(0,20,40,0) # From SB9 catalogue. In real world, I wouldnt know this first hand

# %% [markdown]
# ## Radial Velocity for 40 random observations:

# %%
 # Seeding the randomness
np.random.seed(SEED)
rand = np.random.randint(0,1825,40)

# %%
def Gaia_transits(gamma,K,P,tau):
    RV = []

    for t in rand:
        v = (2*math.pi)*(t-tau)/P
        RV.append(gamma + K*np.cos(v))
    plt.figure(figsize=(20,2))
    plt.plot(rand,RV,'s')
    plt.xlabel('time in days', fontsize=14)
    plt.ylabel('Radial Velocity in km/s', fontsize=14)
    return RV

Gaia_transit = Gaia_transits(0,20,40,0)

# %%
def complete_binary_plot():

    plt.figure(figsize=(20,2))
    plt.plot(binary)
    plt.plot(rand,Gaia_transit,'s')
    plt.xlabel('time in days', fontsize=14)
    plt.ylabel('Radial Velocity in km/s', fontsize=14)
    plt.title('Binary model with the 40 random Gaia transits',fontsize=16)
    plt.show()
complete_binary_plot()

# %% [markdown]
# Approximating that Gaia scan law.

# %% [markdown]
# ---

# %% [markdown]
# #### Convolving flux with a Gaussian Line Spread Function

# %%
convolved_flux = scipy.ndimage.gaussian_filter1d(data.flux,sig_rvs)

# %% [markdown]
# revised parameters

# %% [markdown]
# resample here:

# %% [markdown]
# inherent from photon electron capture

# %% [markdown]
# gaussian noise is uncertainty just from reading from a detector.

# %%
#b = noise[0]
#y1_norm = np.median(noise[0:51])
#y2_norm = np.median(noise[-51:-1])
#linear_flux2 = np.zeros((n),float)
#grad_norm = (y2_norm-y1_norm)/(x2-x1)
#for i in range(0,n-1):
#    linear_flux2[i] = b + (grad_norm*i)

# %%
wavelength = data.wavelength.to_numpy()
wavelength
# Out:
# array([840.   , 840.001, 840.002, ..., 889.998, 889.999, 890.   ])

# %%
rvs_wavelength = np.arange(840,890,0.025)
rvs_flux = spectres.spectres(rvs_wavelength,wavelength,convolved_flux)
rvs_flux = np.nan_to_num(rvs_flux, nan=47619.2)
# Out:
# Spectres: new_wavs contains values outside the range in spec_wavs, new_fluxes and new_errs will be filled with the value set in the 'fill' keyword argument.

# %% [markdown]
# Resampling new template:

# %%
def norm_flux_array_rvs():
    

    rvs_flux_size = rvs_flux.size

    x1_rvs = 25
    x2_rvs = rvs_flux_size-1-25
    y1_rvs = np.median(rvs_flux[0:51])
    y2_rvs = np.median(rvs_flux[-51:-1])
    rvs_first_flux_point = rvs_flux[0]
    gradient_rvs = (y2_rvs-y1_rvs)/(x2_rvs-x1_rvs)
    linear_flux_rvs = np.zeros((rvs_flux_size),float)
    for i in range(0,rvs_flux_size-1):
        linear_flux_rvs[i] = rvs_first_flux_point + (gradient_rvs)*i
    """Normalising the convolved flux"""
    norm_flux_array_rvs = rvs_flux/linear_flux_rvs
    plt.figure(figsize=(20,5))
    plt.plot(rvs_wavelength,norm_flux_array_rvs,'b')
    plt.show()
    return norm_flux_array_rvs

# %%
norm_flux_array_rvs()
# Out:
# array([1.        , 1.00005318, 1.00004589, ..., 1.00052764, 0.99968679,
#               inf])

# %% [markdown]
# RVS wavelength range: 846-870nm:

# %% [markdown]
# Doppler Shifting the full spectra wrt the 40 RV's calculated earlier:

# %%
def doppler_shift_spectra():
    flux = []
    wlprime = []

    for i in range(40):
        flux.append(pyasl.dopplerShift(rvs_wavelength, norm_flux_array_rvs,binary_model[i])[0])
        wlprime.append(pyasl.dopplerShift(rvs_wavelength, norm_flux_array_rvs,radvel_gaia[i])[1])

# %%
doppler_shift_spectra()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Documents/MSc_Thesis/Cross Correlation Function.py in <module>
# ----> 1 doppler_shift_spectra()
#
# ~/Documents/MSc_Thesis/Cross Correlation Function.py in doppler_shift_spectra()
#       4
#       5     for i in range(40):
# ----> 6         flux.append(pyasl.dopplerShift(rvs_wavelength, norm_flux_array_rvs,binary_model[i])[0])
#       7         wlprime.append(pyasl.dopplerShift(rvs_wavelength, norm_flux_array_rvs,radvel_gaia[i])[1])
#       8
#
# NameError: name 'binary_model' is not defined

# %%
nflux = []
wlprime = []

for i in range(40):
    nflux.append(pyasl.dopplerShift(rvs_wl, norm_flux_array2,radvel_gaia[i])[0])
    wlprime.append(pyasl.dopplerShift(rvs_wl, norm_flux_array2,radvel_gaia[i])[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Documents/MSc_Thesis/Cross Correlation Function.py in <module>
#       3
#       4 for i in range(40):
# ----> 5     nflux.append(pyasl.dopplerShift(rvs_wl, norm_flux_array2,radvel_gaia[i])[0])
#       6     wlprime.append(pyasl.dopplerShift(rvs_wl, norm_flux_array2,radvel_gaia[i])[1])
#
# NameError: name 'rvs_wl' is not defined

# %% [markdown]
# Slicing these shifted spectra to fit the RVS wavelength range:

# %%
# %%time
nflux_rvs = []
wlprime_rvs = []

for i in range(40):
    nflux_rvs.append(pyasl.dopplerShift(rvs_wl, norm_flux_array2,radvel_gaia[i])[0][240:1200])
    wlprime_rvs.append(pyasl.dopplerShift(rvs_wl, norm_flux_array2,radvel_gaia[i])[1][240:1200])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Documents/MSc_Thesis/Cross Correlation Function.py in <module>
#
# NameError: name 'norm_flux_array2' is not defined

# %% [markdown]
# ---

# %% [markdown]
# #### Cross Correlating

# %% [markdown]
# Cross correlating the template at rest to double check:

# %%
# %%time
rv_tem, cc_tem = crosscorrRV(rvs_wl[240:1200],norm_flux_array2[240:1200],tw_series,norm_flux_array,-1000.,1000.,1.,mode='doppler',skipedge=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Documents/MSc_Thesis/Cross Correlation Function.py in <module>
#
# NameError: name 'norm_flux_array2' is not defined

# %% [markdown]
# Cross correlating our shifted spectra with respect to the template

# %%
# %%time
rv = []
cc = []

for i in range(40):
    rv.append(crosscorrRV(wlprime_rvs[i],nflux_rvs[i],tw_series,norm_flux_array,-1000.,1000.,1.,mode='doppler',skipedge=0)[0])
    cc.append(crosscorrRV(wlprime_rvs[i],nflux_rvs[i],tw_series,norm_flux_array,-1000.,1000.,1.,mode='doppler',skipedge=0)[1])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~/Documents/MSc_Thesis/Cross Correlation Function.py in <module>
#
# IndexError: list index out of range

# %%
# %%time
plt.figure(figsize=(20,15))
maxind_tem = np.argmax(cc_tem)
print("Template cross-correlation function is maximized at RV = ", rv_tem[maxind_tem], " km/s")
maxind = [np.argmax(cc[i]) for i in range(40)]

plt.plot(rv_tem,cc_tem,'k')
for i in range(40):
    plt.plot(rv[i],cc[i])
    print("Cross-correlation function is maximized at RV = ", rv[i][maxind[i]], " km/s")
    plt.xlabel("Radial velocity in km/s", fontsize=14)
    plt.ylabel("Cross-correlation coefficient", fontsize=14)
    plt.xlim(-50,50)
    
    if rv[i][maxind[i]] > 0.0:
        print("  A red-shift with respect to the template")
    else:
        print("  A blue-shift with respect to the template")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~/Documents/MSc_Thesis/Cross Correlation Function.py in <module>
#
# NameError: name 'cc_tem' is not defined

# %% [markdown]
# #### Note: The cross correlation works. A systematic error by a factor of 2 is present from all doppler shift km/s. Do not know why this is.

# %% [markdown]
# ---

# %%
# %%time
cc_test = []
for j in range(2000):
    for i in range(40):
        cc_test.append(cc[i][j])
split = [cc_test[x:x+40] for x in range(0,len(cc_test),40)]

totals = []
for i in range(len(split)):
    sums = sum(split[i])
    sums = sums/40
    totals.append(sums)
# Out:
# CPU times: user 28.8 ms, sys: 2.6 ms, total: 31.4 ms
# Wall time: 30.2 ms

# %%
plt.figure(figsize=(20,15))
plt.plot(rv_tem,totals)
plt.xlabel("Radial velocity in km/s",fontsize=14)
plt.ylabel("Cross-correlation coefficient",fontsize=14)
plt.show()
#Gaia DR3 illustration

# %% [markdown]
# Reversing the signs of the velocity to get the opposite:

# %%
def reverse_signs(lst): 
    return [ -i for i in lst ]
radvel_gaia_rev = reverse_signs(radvel_gaia)

# %%
# %%time
back_shift_rv = []
for i in range(40):
    back_shift_rv.append(rv[i]+(radvel_gaia_rev[i]*2))
# Out:
# CPU times: user 1.44 ms, sys: 1.14 ms, total: 2.59 ms
# Wall time: 2.46 ms

# %% [markdown]
# consider this

# %%
# %%time
plt.figure(figsize=(20,15))
for i in range(40):
    plt.plot(back_shift_rv[i],cc[i])
    plt.title('CCfs with RV shifted to rest (RV=0) according to the binary model', fontsize=14)
    plt.xlabel("Radial velocity in km/s", fontsize=14)
    plt.ylabel("Cross-correlation coefficient", fontsize=14)
# Out:
# CPU times: user 39 ms, sys: 4.52 ms, total: 43.6 ms
# Wall time: 41.9 ms

# %% [markdown]
# the reverse doppler shift is the "shortcut" instead of brute force.

# %%
tot_rv = np.arange(-1000,1001,1)

# %% [markdown]
# Resampling is used to put all the RV's on the same plot/axis and "space." therefore at each RV bin we can average each CCF.

# %%
# %%time
cc_interp = []

plt.figure(figsize=(20,15))
for i in range(40):
    cc_interp.append(np.interp(tot_rv,back_shift_rv[i],cc[i]))
    plt.plot(tot_rv,cc_interp[i],'s')
    plt.title('RV shifted to rest (RV=0) according to binary model', fontsize=14)
    plt.xlabel("Radial velocity in km/s",fontsize=14)
    plt.ylabel("Cross-correlation coefficient",fontsize=14)
# Out:
# CPU times: user 37.8 ms, sys: 2.34 ms, total: 40.1 ms
# Wall time: 39.5 ms

# %% [markdown]
# ---

# %%
# %%time
cc_interp_test = [cc_interp[i][j] for j in range(2000) for i in range(40)]
split_interp = [cc_interp_test[x:x+40] for x in range(0,len(cc_interp_test),40)]
# Out:
# CPU times: user 11.9 ms, sys: 1.39 ms, total: 13.3 ms
# Wall time: 12.9 ms

# %%
# %%time
sums_new = [sum(split_interp[i]) for i in range(len(split_interp))]
totals_interp = [sums_new[i]/40 for i in range(len(split_interp))]
# Out:
# CPU times: user 8.28 ms, sys: 287 µs, total: 8.57 ms
# Wall time: 8.61 ms

# %%
tot_rv_less = np.arange(-1000,1000,1)
plt.figure(figsize=(20,15))
plt.plot(tot_rv_less,totals_interp)
plt.show()

# %% [markdown]
# good result.

# %% [markdown]
# ---

# %% [markdown]
# ---

# %%
from numpy import pi, log, sqrt
import pypolychord
from pypolychord.settings import PolyChordSettings
from pypolychord.priors import UniformPrior
# Out:
# WARNING: Could not preload libmpi.so.If you are running with MPI, this may cause segfaults

# %% [markdown]
# Sampling method - Position:

# %%
# %time
nDims = 4
nDerived = 0
sigma = 0.1
def likelihood(theta):
    gamma = theta[0]
    K = theta[1]
    P = theta[2]
    tau = theta[3]
    
    """ Obtaining RV values """
    
    RV_sample = []
    for t in rand:
        v = (2*math.pi)*(t-tau)/P
        RV_sample.append(gamma + K*np.cos(v))
        
    """ Reversing RV values for original 40 values that were just obtained """
    radvel_gaia_rev_sample = [-x for x in RV_sample]
    
    """ Shifting back the original CCF's from earlier by the RV values obtained in the previous step """
    back_shift_rv2 = []
    for i in range(40):
        curve = np.asarray(rv[i]+(radvel_gaia_rev_sample[i]*2))
        back_shift_rv2.append(curve[cc[i]==max(cc[i])])
    back_shift_rv2 = np.asarray(back_shift_rv2) # done because **2 does not work for lists, so switched to np.array

    
    return -sum(back_shift_rv2**2)[0], []
# good for bright stars, not so good for faint as you would evidently shift noise as well as fainter stars
# Out:
# CPU times: user 4 µs, sys: 4 µs, total: 8 µs
# Wall time: 16.7 µs

# %%
def prior(hypercube):
    prior = []
    prior.append(UniformPrior(-1000, 1000)(hypercube[0])) # Gaia search region
    prior.append(UniformPrior(0, 600)(hypercube[1])) # Semi amplituder range from SB9
    prior.append(UniformPrior(0, 1000)(hypercube[2])) # Period range from SB9
    prior.append(UniformPrior(0, 1825)(hypercube[3])) # 5 year nominal mission in days
    return prior

# %%
def dumper(live, dead, logweights, logZ, logZerr):
    print("Last dead point:", dead[-1])

# %%
settings = PolyChordSettings(nDims, nDerived)
settings.file_root = 'gaussian'
settings.nlive = 300
settings.do_clustering = True
settings.read_resume = False

# %%
# %time
output = pypolychord.run_polychord(likelihood, nDims, nDerived, settings, prior, dumper)

# %%
#paramnames = [('p%i' % i, r'\theta_%i' % i) for i in range(nDims)]
paramnames = [('cc_coeff', 'gamma'),('cc_coeff', 'K'),('cc_coeff','p'), ('cc_coeff', 'tau')]
output.make_paramnames_files(paramnames)
paramnames

# %%
try:
    from anesthetic import NestedSamples
    samples = NestedSamples(root= settings.base_dir + '/' + settings.file_root)
    fig, axes = samples.plot_2d(paramnames)
    fig.savefig('posterior position.pdf')

except ImportError:
    try:
        import getdist.plots
        posterior = output.posterior
        g = getdist.plots.getSubplotPlotter()
        g.triangle_plot(posterior, filled=True)
        g.export('posterior.pdf')
    except ImportError:
        print("Install matplotlib and getdist for plotting examples")

    print("Install anesthetic or getdist  for for plotting examples")

# %%
gaussian = pd.read_fwf('/users/azib/documents/msc_thesis/chains/gaussian.txt')

# %%
gaussian.columns = ['weights','likelihood','gamma','K','P','tau']

# %%
gaussian

# %%
max_l = gaussian.loc[gaussian['likelihood'].idxmax()]
max_l

# %% [markdown]
# ---

# %% [markdown]
# Sampling method - Height:

# %%
# %%time
nDims = 4
nDerived = 0
sigma = 0.1
def sample(theta):
    gamma = theta[0]
    K = theta[1]
    P = theta[2]
    tau = theta[3]
    
    """ Obtaining RV values """
    
    RV_sample = []
    for t in rand:
        v = (2*math.pi)*(t-tau)/P
        RV_sample.append(gamma + K*np.cos(v))
        
    """ Reversing RV values for original 40 values that were just obtained """
    radvel_gaia_rev_sample = [-x for x in RV_sample]
    
    """ Shifting back the original CCF's from earlier by the RV values obtained in the previous step """
    back_shift_rv2 = [(rv[i]+(radvel_gaia_rev_sample[i]*2)) for i in range(40)]

    """ resmapling onto a new template from -1000 to 1000 in steps of 1km/s """
    tot_rv = np.arange(-1000,1000,1)
    cc_interp = [np.interp(tot_rv,back_shift_rv2[i],cc[i]) for i in range(40)]

    """ splitting the sample into batches of 40 to be able to perform the next step """

    cc_interp_test = [cc_interp[i][j] for j in range(2000) for i in range(40)]
    split_interp = [cc_interp_test[x:x+40] for x in range(0,len(cc_interp_test),40)]
            
    """ taking each index of the 40 values and performing averaging calculations """
        
    sums_new = [sum(split_interp[i]) for i in range(len(split_interp))]
    totals_interp = [sums_new[i]/40 for i in range(len(split_interp))]
    
  
    return max(totals_interp)**2, []

# %%
def prior(hypercube):
    prior = []
    prior.append(UniformPrior(-1000, 1000)(hypercube[0])) # Gaia search region
    prior.append(UniformPrior(0, 600)(hypercube[1])) # Semi amplituder range from SB9
    prior.append(UniformPrior(0, 1000)(hypercube[2])) # Period range from SB9
    prior.append(UniformPrior(0, 1825)(hypercube[3])) # 5 year nominal mission in days
    return prior

# %%
def dumper(live, dead, logweights, logZ, logZerr):
    print("Last dead point:", dead[-1])

# %%
settings_height = PolyChordSettings(nDims, nDerived)
settings_height.file_root = 'gaussian height'
settings_height.nlive = 300
settings_height.do_clustering = True
settings_height.read_resume = False

# %%
# %time
output = pypolychord.run_polychord(sample, nDims, nDerived, settings_height, prior, dumper)

# %%
paramnames = [('p%i' % i, r'\theta_%i' % i) for i in range(nDims)]
#paramnames = [('cc_coeff', '\\gamma'),('cc_coeff', '\\K'),('cc_coeff','\\p'), ('cc_coeff', '\\tau')]
output.make_paramnames_files(paramnames)

# %%
try:
    from anesthetic import NestedSamples
    samples = NestedSamples(root= settings_height.base_dir + '/' + settings_height.file_root)
    fig, axes = samples.plot_2d(['p0','p1','p2','p3'])
    fig.savefig('posterior height.pdf')

except ImportError:
    try:
        import getdist.plots
        posterior = output.posterior
        g = getdist.plots.getSubplotPlotter()
        g.triangle_plot(posterior, filled=True)
        g.export('posterior.pdf')
    except ImportError:
        print("Install matplotlib and getdist for plotting examples")

    print("Install anesthetic or getdist  for for plotting examples")

# %%
gaussian_height = pd.read_fwf('/users/azib/documents/msc_thesis/chains/gaussian height.txt')

# %%
gaussian_height.columns = ['weights','likelihood','gamma','K','P','tau']

# %%
max_l_height = gaussian_height.loc[gaussian_height['likelihood'].idxmax()]
max_l_height
